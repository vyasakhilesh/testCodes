# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
california_housing_dataframe = pd.read_csv("https://storage.googleapis.com/mledu-datasets/california_housing_train.csv", sep=",")
california_housing_dataframe = california_housing_dataframe.reindex(
    np.random.permutation(california_housing_dataframe.index))
df = california_housing_dataframe[0:4]
california_housing_dataframe.hist(bins=20,figsize=(10,10))
plt.show()
print df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3538     -117.90     33.66                22.0       3568.0           938.0
# 15776    -122.41     37.79                52.0       2909.0           851.0
# 13162    -121.89     37.32                43.0       1105.0           241.0
# 7741     -118.38     33.95                29.0       1821.0           588.0
#
#        population  households  median_income  median_house_value
# 3538       1952.0       938.0         3.1667            161000.0
# 15776      1711.0       830.0         3.0296            500001.0
# 13162       982.0       206.0         2.1149            184900.0
# 7741       1397.0       523.0         2.5833            187500.0

# %%
def linear_scale(series):
    min_val = series.min()
    print min_val
    print min_val.shape
    max_val = series.max()
    print max_val
    scale = (max_val - min_val) / 2.0
    print scale
    print scale.shape
    return series.apply(lambda x:((x - min_val) / scale) - 1.0)
p = linear_scale(df)
print "df:", df
print "p: ",p
# Out:
# longitude               -122.4100
# latitude                  33.6600
# housing_median_age        22.0000
# total_rooms             1105.0000
# total_bedrooms           241.0000
# population               982.0000
# households               206.0000
# median_income              2.1149
# median_house_value    161000.0000
# dtype: float64
# (9,)
# longitude               -117.9000
# latitude                  37.7900
# housing_median_age        52.0000
# total_rooms             3568.0000
# total_bedrooms           938.0000
# population              1952.0000
# households               938.0000
# median_income              3.1667
# median_house_value    500001.0000
# dtype: float64
# longitude                  2.2550
# latitude                   2.0650
# housing_median_age        15.0000
# total_rooms             1231.5000
# total_bedrooms           348.5000
# population               485.0000
# households               366.0000
# median_income              0.5259
# median_house_value    169500.5000
# dtype: float64
# (9,)
# df:        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3538     -117.90     33.66                22.0       3568.0           938.0
# 15776    -122.41     37.79                52.0       2909.0           851.0
# 13162    -121.89     37.32                43.0       1105.0           241.0
# 7741     -118.38     33.95                29.0       1821.0           588.0
#
#        population  households  median_income  median_house_value
# 3538       1952.0       938.0         3.1667            161000.0
# 15776      1711.0       830.0         3.0296            500001.0
# 13162       982.0       206.0         2.1149            184900.0
# 7741       1397.0       523.0         2.5833            187500.0
# p:                      longitude  latitude  housing_median_age  total_rooms  \
# 3538                      NaN       NaN                 NaN          NaN
# 7741                      NaN       NaN                 NaN          NaN
# 13162                     NaN       NaN                 NaN          NaN
# 15776                     NaN       NaN                 NaN          NaN
# households                NaN       NaN                 NaN          NaN
# housing_median_age        NaN       NaN                 NaN          NaN
# latitude                  NaN       NaN                 NaN          NaN
# longitude                 NaN       NaN                 NaN          NaN
# median_house_value        NaN       NaN                 NaN          NaN
# median_income             NaN       NaN                 NaN          NaN
# population                NaN       NaN                 NaN          NaN
# total_bedrooms            NaN       NaN                 NaN          NaN
# total_rooms               NaN       NaN                 NaN          NaN
#
#                     total_bedrooms  population  households  median_income  \
# 3538                           NaN         NaN         NaN            NaN
# 7741                           NaN         NaN         NaN            NaN
# 13162                          NaN         NaN         NaN            NaN
# 15776                          NaN         NaN         NaN            NaN
# households                     NaN         NaN         NaN            NaN
# housing_median_age             NaN         NaN         NaN            NaN
# latitude                       NaN         NaN         NaN            NaN
# longitude                      NaN         NaN         NaN            NaN
# median_house_value             NaN         NaN         NaN            NaN
# median_income                  NaN         NaN         NaN            NaN
# population                     NaN         NaN         NaN            NaN
# total_bedrooms                 NaN         NaN         NaN            NaN
# total_rooms                    NaN         NaN         NaN            NaN
#
#                     median_house_value
# 3538                               NaN
# 7741                               NaN
# 13162                              NaN
# 15776                              NaN
# households                         NaN
# housing_median_age                 NaN
# latitude                           NaN
# longitude                          NaN
# median_house_value                 NaN
# median_income                      NaN
# population                         NaN
# total_bedrooms                     NaN
# total_rooms                        NaN

# %%
t = np.arange(1,9,1)
y = t.reshape((2,4,1))
np.squeeze(y, axis=2)
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])
